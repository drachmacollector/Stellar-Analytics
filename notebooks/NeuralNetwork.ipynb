# %% [markdown]
# # Neural Network

# %% [markdown]
# ## Imports

# %%
import os
import random
import numpy as np
import pandas as pd
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# **Reproducibility**

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
df = pd.read_csv("[CLEANED]supernova-dataset.csv")

# %% [markdown]
# ## Defining X and y

# %%
df = df[df["koi_disposition"] != "CANDIDATE"].copy()

df["target"] = (df["koi_disposition"] == "CONFIRMED").astype(int)

drop_cols = ["Unnamed: 0", "kepid", "koi_disposition"]
X = df.drop(columns=drop_cols + ["target"])
y = df["target"]

# %% [markdown]
# ## Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=SEED
)

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

os.makedirs("models", exist_ok=True)
joblib.dump(scaler, "models/nn_scaler.pkl")
# Out:
# ['models/nn_scaler.pkl']

# %% [markdown]
# ## Class weights

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))

# %% [markdown]
# ## Model Architecture

# %%
def build_model(input_dim):
    model = keras.Sequential([
        keras.Input(shape=(input_dim,)),  # <-- fix here

        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(128, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.2),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[keras.metrics.AUC(name="auc")]
    )

    return model

# %% [markdown]
# ## Early Stopping

# %%
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

# %% [markdown]
# ## Training

# %%
model = build_model(X_train.shape[1])

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    class_weight=class_weights,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - auc: 0.8406 - loss: 0.5180 - val_auc: 0.9471 - val_loss: 0.4368
# Epoch 2/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9265 - loss: 0.3493 - val_auc: 0.9502 - val_loss: 0.3653
# Epoch 3/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9310 - loss: 0.3366 - val_auc: 0.9534 - val_loss: 0.3072
# Epoch 4/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9378 - loss: 0.3208 - val_auc: 0.9556 - val_loss: 0.2869
# Epoch 5/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9418 - loss: 0.3088 - val_auc: 0.9559 - val_loss: 0.2770
# Epoch 6/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9439 - loss: 0.3010 - val_auc: 0.9569 - val_loss: 0.2764
# Epoch 7/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9452 - loss: 0.2970 - val_auc: 0.9588 - val_loss: 0.2763
# Epoch 8/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9476 - loss: 0.2913 - val_auc: 0.9592 - val_loss: 0.2667
# Epoch 9/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9505 - loss: 0.2820 - val_auc: 0.9606 - val_loss: 0.2629
# Epoch 10/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9493 - loss: 0.2862 - val_auc: 0.9606 - val_loss: 0.2627
# Epoch 11/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9529 - loss: 0.2752 - val_auc: 0.9629 - val_loss: 0.2563
# Epoch 12/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9557 - loss: 0.2667 - val_auc: 0.9627 - val_loss: 0.2493
# Epoch 13/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9574 - loss: 0.2606 - val_auc: 0.9636 - val_loss: 0.2537
# Epoch 14/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9583 - loss: 0.2590 - val_auc: 0.9627 - val_loss: 0.2540
# Epoch 15/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9557 - loss: 0.2644 - val_auc: 0.9639 - val_loss: 0.2523
# Epoch 16/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9607 - loss: 0.2505 - val_auc: 0.9638 - val_loss: 0.2517
# Epoch 17/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9589 - loss: 0.2553 - val_auc: 0.9646 - val_loss: 0.2552
# Epoch 18/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9597 - loss: 0.2523 - val_auc: 0.9648 - val_loss: 0.2486
# Epoch 19/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9612 - loss: 0.2465 - val_auc: 0.9650 - val_loss: 0.2452
# Epoch 20/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9628 - loss: 0.2402 - val_auc: 0.9660 - val_loss: 0.2421
# Epoch 21/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9626 - loss: 0.2413 - val_auc: 0.9657 - val_loss: 0.2464
# Epoch 22/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9646 - loss: 0.2361 - val_auc: 0.9662 - val_loss: 0.2401
# Epoch 23/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9658 - loss: 0.2318 - val_auc: 0.9659 - val_loss: 0.2375
# Epoch 24/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9663 - loss: 0.2295 - val_auc: 0.9655 - val_loss: 0.2386
# Epoch 25/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9681 - loss: 0.2229 - val_auc: 0.9669 - val_loss: 0.2424
# Epoch 26/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9671 - loss: 0.2257 - val_auc: 0.9666 - val_loss: 0.2403
# Epoch 27/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9691 - loss: 0.2199 - val_auc: 0.9677 - val_loss: 0.2300
# Epoch 28/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9669 - loss: 0.2266 - val_auc: 0.9674 - val_loss: 0.2354
# Epoch 29/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9682 - loss: 0.2212 - val_auc: 0.9668 - val_loss: 0.2364
# Epoch 30/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9677 - loss: 0.2253 - val_auc: 0.9679 - val_loss: 0.2359
# Epoch 31/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9711 - loss: 0.2122 - val_auc: 0.9697 - val_loss: 0.2277
# Epoch 32/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9707 - loss: 0.2128 - val_auc: 0.9679 - val_loss: 0.2356
# Epoch 33/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9717 - loss: 0.2096 - val_auc: 0.9689 - val_loss: 0.2333
# Epoch 34/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9737 - loss: 0.2032 - val_auc: 0.9689 - val_loss: 0.2421
# Epoch 35/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9727 - loss: 0.2045 - val_auc: 0.9682 - val_loss: 0.2451
# Epoch 36/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9762 - loss: 0.1910 - val_auc: 0.9659 - val_loss: 0.2462
# Epoch 37/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9740 - loss: 0.1992 - val_auc: 0.9678 - val_loss: 0.2423
# Epoch 38/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9725 - loss: 0.2042 - val_auc: 0.9670 - val_loss: 0.2448
# Epoch 39/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9730 - loss: 0.2051 - val_auc: 0.9684 - val_loss: 0.2361
# Epoch 40/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.9758 - loss: 0.1927 - val_auc: 0.9659 - val_loss: 0.2423
# Epoch 41/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9762 - loss: 0.1933 - val_auc: 0.9682 - val_loss: 0.2460

# %% [markdown]
# ## metrics

# %% [markdown]
# **find best threshold for F1**
#
# ```
# thresholds = np.linspace(0.1, 0.9, 100)
# best_f1 = 0
# best_thresh = 0.5
#
# for t in thresholds:
#     preds = (y_probs >= t).astype(int)
#     score = f1_score(y_test, preds)
#     if score > best_f1:
#         best_f1 = score
#         best_thresh = t
# ```

# %%
y_probs = model.predict(X_test)
y_pred = (y_probs >= 0.5).astype(int)

print("F1:", f1_score(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_probs))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# F1: 0.8602878916172735
# ROC-AUC: 0.9588418253241481
# [[789 124]
#  [ 41 508]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.91       913
#            1       0.80      0.93      0.86       549
#
#     accuracy                           0.89      1462
#    macro avg       0.88      0.89      0.88      1462
# weighted avg       0.90      0.89      0.89      1462

# %% [markdown]
# ## saving

# %%
model.save("models/nn_model.keras")
